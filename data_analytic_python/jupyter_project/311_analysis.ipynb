# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

url = "https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/311_Service_Requests_from_2019May.csv"
# load the data into dataframe
df = pd.read_csv(url)
# # list columns intended to be parsed as dates, if they exist in the file
date_cols = ['Created Date', 'Closed Date', 'Resolution Action Updated Date']

# reload data with types and date columns
df = pd.read_csv(
    url,
    low_memory=False,
    dtype={'Incident Zip': "string", 'Zip': "string", 'Vehicle Type': "string"},
    parse_dates=[c for c in date_cols if c in pd.read_csv(url, nrows=0).columns]
)

df.head() # show the first 5 rows of the dataframe
# Out:
# /var/folders/cq/6pbw3dq526d9497jktl4tdxc0000gp/T/ipykernel_12223/2684465153.py:8: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(url)
#    Unique Key Created Date         Closed Date Agency  Complaint Type  \
# 0    42680103   2019-05-01 2019-05-16 21:45:00    DEP    Water System
# 1    42530481   2019-05-01 2019-05-02 00:00:00  DOHMH  Food Poisoning
# 2    42527619   2019-05-01 2019-05-13 00:00:00  DOHMH  Food Poisoning
# 3    42526597   2019-05-01 2019-05-02 00:00:00  DOHMH  Food Poisoning
# 4    42526595   2019-05-01 2019-05-02 00:00:00  DOHMH  Food Poisoning
#
#                 Location Type Incident Zip             Incident Address  \
# 0                         NaN        11420            127-16 111 AVENUE
# 1  Restaurant/Bar/Deli/Bakery        10011         207 WEST   14 STREET
# 2  Restaurant/Bar/Deli/Bakery        10025                2664 BROADWAY
# ...
